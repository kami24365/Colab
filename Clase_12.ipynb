# %% [markdown]
# <a href="https://colab.research.google.com/github/kami24365/Colab/blob/main/Clase_12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Limpieza y transformación de datos**
#
# El procesos de preprocesamiento de datos se lleva a cabo una vez hemos explorado y limpiado nuestro conjunto de datos, de modo que entendamos su contenido, estructura y calidad. Al explorar nuestros datos, es probable que obtengamos una buena idea de cómo queremos modelarlos, lo cual nos ayudará a decidir la mejor manera de preprocesarlos para que stén listos para el modelado desde el principio.

# %%
# Importar pandas
import pandas as pd

# %%
# Importar desde Drive

df=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Archivos clase/clientes.csv")
df
# Out:
#      ID del cliente           Nombre Última fecha de compra  \
# 0                 1       Juan Perez             15/03/2022
# 1                 2    Ana Rodriguez             01/04/2022
# 2                 3  Luisa Hernandez             10/12/2021
# 3                 4    Carlos Garcia             28/02/2022
# 4                 5      Maria Gomez             20/03/2022
# ..              ...              ...                    ...
# 152             160      Andrea Soto             09/06/2022
# 153             161  Laura Hernandez             06/06/2022
# 154             145      Luis Garcia             04/06/2022
# 155             154      Luisa Perez             08/06/2022
# 156             160      Andrea Soto             09/06/2022
#
#      Frecuencia de compra  Valor promedio de la compra  \
# 0                       5                        200.5
# 1                       2                         80.0
# 2                       3                        150.2
# ...

# %%
# Muestra los primeros 5 registros
df.head()
# Out:
#    ID del cliente           Nombre Última fecha de compra  \
# 0               1       Juan Perez             15/03/2022
# 1               2    Ana Rodriguez             01/04/2022
# 2               3  Luisa Hernandez             10/12/2021
# 3               4    Carlos Garcia             28/02/2022
# 4               5      Maria Gomez             20/03/2022
#
#    Frecuencia de compra  Valor promedio de la compra  \
# 0                     5                        200.5
# 1                     2                         80.0
# 2                     3                        150.2
# 3                     1                        300.0
# 4                     4                         75.8
#
#   Categoría de productos comprados          Método de pago  Edad
# 0                             Ropa      Tarjeta de crédito  32.0
# 1                         Juguetes                Efectivo  45.0
# 2                      Electrónica  Transferencia bancaria  28.0
# ...

# %%
# Muestra los últimos 5 registros
df.tail()
# Out:
#      ID del cliente           Nombre Última fecha de compra  \
# 152             160      Andrea Soto             09/06/2022
# 153             161  Laura Hernandez             06/06/2022
# 154             145      Luis Garcia             04/06/2022
# 155             154      Luisa Perez             08/06/2022
# 156             160      Andrea Soto             09/06/2022
#
#      Frecuencia de compra  Valor promedio de la compra  \
# 152                     2                         50.0
# 153                     1                        120.0
# 154                     4                         75.2
# 155                     2                         80.0
# 156                     2                         50.0
#
#     Categoría de productos comprados          Método de pago  Edad
# 152                      Electrónica  Transferencia bancaria  25.0
# 153                        Alimentos                Efectivo  39.0
# 154                        Alimentos  Transferencia bancaria  28.0
# ...

# %%
# Muestra información de los registros
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 8 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   ID del cliente                    157 non-null    int64
#  1   Nombre                            155 non-null    object
#  2   Última fecha de compra            156 non-null    object
#  3   Frecuencia de compra              157 non-null    int64
#  4   Valor promedio de la compra       152 non-null    float64
#  5   Categoría de productos comprados  151 non-null    object
#  6   Método de pago                    153 non-null    object
#  7   Edad                              154 non-null    float64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 9.9+ KB

# %%
# Muestra información estadística de la data
df.describe()
# Out:
#        ID del cliente  Frecuencia de compra  Valor promedio de la compra  \
# count      157.000000            157.000000                    152.00000
# mean        82.579618              2.369427                    118.23750
# std         47.555248              1.172804                    249.86509
# min          1.000000              1.000000                     20.00000
# 25%         42.000000              1.000000                     65.20000
# 50%         83.000000              2.000000                     85.10000
# 75%        124.000000              3.000000                    120.28750
# max        161.000000              5.000000                   3110.00000
#
#              Edad
# count  154.000000
# mean    31.233766
# std      9.146443
# min      1.000000
# 25%     26.000000
# 50%     30.000000
# 75%     37.000000
# max     80.000000

# %%
# Obtener la cantidad de nulos por columna

df.isnull().sum()
# Out:
# ID del cliente                      0
# Nombre                              2
# Última fecha de compra              1
# Frecuencia de compra                0
# Valor promedio de la compra         5
# Categoría de productos comprados    6
# Método de pago                      4
# Edad                                3
# dtype: int64

# %%
# Eliminar valores nulos en específico

df = df.drop([16,17,39])

df.head(20)
# Out:
#     ID del cliente            Nombre Última fecha de compra  \
# 0                1        Juan Perez             15/03/2022
# 1                2     Ana Rodriguez             01/04/2022
# 2                3   Luisa Hernandez             10/12/2021
# 3                4     Carlos Garcia             28/02/2022
# 4                5       Maria Gomez             20/03/2022
# 5                6     Daniel Torres             12/04/2022
# 6                7        Lucia Diaz             29/03/2022
# 7                8       Pedro Lopez             30/11/2021
# 8                9    Sofia Gonzalez             15/01/2022
# 9               10     Andres Suarez             20/04/2022
# 10              11      Laura Castro             10/03/2022
# 11              12     Oscar Ramirez             15/02/2022
# 12              13    Ana Maria Vega             05/01/2022
# 13              14       Luis Torres             18/04/2022
# 14              15     Andrea Medina             23/03/2022
# ...

# %%
#Verificar las edades que contengan valores nulos

df[df['Edad'].isnull()]
# Out:
#      ID del cliente         Nombre Última fecha de compra  \
# 52               55  Carlos Moreno             14/03/2022
# 84               89   David Torres             23/03/2022
# 107             114  Maria Sanchez             11/05/2022
#
#      Frecuencia de compra  Valor promedio de la compra  \
# 52                      1                        210.0
# 84                      3                         75.6
# 107                     1                        110.0
#
#     Categoría de productos comprados          Método de pago  Edad
# 52                          Juguetes      Tarjeta de crédito   NaN
# 84                         Alimentos  Transferencia bancaria   NaN
# 107                             Ropa                     NaN   NaN

# %%
# Eliminar edades que no tengan valores

df = df.drop([52,84,107])

# %%
# Saber valores nulos en la columna nombre
df[df["Nombre"].isnull()]
# Out:
#      ID del cliente Nombre Última fecha de compra  Frecuencia de compra  \
# 142             150    NaN             06/06/2022                     1
# 149             157    NaN             01/06/2022                     2
#
#      Valor promedio de la compra Categoría de productos comprados  \
# 142                        100.0                             Ropa
# 149                         35.5                        Alimentos
#
#              Método de pago  Edad
# 142                     NaN  28.0
# 149  Transferencia bancaria  38.0

# %%
# Borrar datos donde hay datos faltantes en la columna Nombre
df=df.drop([142,149])

# %%
# Borrar el valor faltante de la fecha de compra
df=df.drop([30])

# %% [markdown]
# # **Tratamiento de valores nulos**
#
# Es colocar 0 en los valores nulos como enteros y decimales.

# %%
# Tratamiento de valores nulos con fillna. Recuerda cargar nuevamente el df, en la celda de código 7

numeric_cols=df.select_dtypes(include=['int64','float64']).columns
df.fillna(df[numeric_cols].mean(axis=0), inplace=True)

# %%
# Eliminar valores atipicos
df= df.drop(df[df["Edad"]<18].index)

# %%
df.tail(80)
# Out:
#      ID del cliente            Nombre Última fecha de compra  \
# 71               75        Ana Torres             02/04/2022
# 73               77   Roberto Ramirez             09/03/2022
# 74               78  Andrea Hernandez             28/04/2022
# 75               79      Pedro Castro             08/05/2022
# 76               80  Monica Rodriguez             30/03/2022
# ..              ...               ...                    ...
# 152             160       Andrea Soto             09/06/2022
# 153             161   Laura Hernandez             06/06/2022
# 154             145       Luis Garcia             04/06/2022
# 155             154       Luisa Perez             08/06/2022
# 156             160       Andrea Soto             09/06/2022
#
#      Frecuencia de compra  Valor promedio de la compra  \
# 71                      1                        140.0
# 73                      2                         35.9
# 74                      1                        100.0
# ...

# %% [markdown]
# # **Eliminar variables irrelevantes**

# %%
# Eliminar variables irrelevantes

df=df.drop(["Nombre"], axis=1)
df
# Out:
#      ID del cliente Última fecha de compra  Frecuencia de compra  \
# 0                 1             15/03/2022                     5
# 1                 2             01/04/2022                     2
# 2                 3             10/12/2021                     3
# 3                 4             28/02/2022                     1
# 4                 5             20/03/2022                     4
# ..              ...                    ...                   ...
# 152             160             09/06/2022                     2
# 153             161             06/06/2022                     1
# 154             145             04/06/2022                     4
# 155             154             08/06/2022                     2
# 156             160             09/06/2022                     2
#
#      Valor promedio de la compra Categoría de productos comprados  \
# 0                          200.5                             Ropa
# ...

# %% [markdown]
# # **Transformación de variables**
#
# ***Codificación one-hot:*** esta tecnica implica crear una columna binaria para cada categoria de la variable categorica. La columna tendra un valor de 1 si la categoria esta presente y tendra un valor de 0 en lo contrario. Pandas tiene una función get_dummies() que realiza esta codificación automáticamente

# %%
# Transformar la variable método de pago

df=pd.get_dummies(df, columns=["Método de pago"])

# %% [markdown]
# ***Codificacion ordinal:*** esta técnica implica asignar un numero único a cada categoria de la variable catégorica en orden de importancia o frecuencia.

# %%
# Transformar la categoria de productos

df["Categoría de productos comprados"]=df["Categoría de productos comprados"].map({"Ropa": 1, "Juguetes": 2, "Electrónica": 3, "Alimentos":4})
df
# Out:
#      ID del cliente Última fecha de compra  Frecuencia de compra  \
# 0                 1             15/03/2022                     5
# 1                 2             01/04/2022                     2
# 2                 3             10/12/2021                     3
# 3                 4             28/02/2022                     1
# 4                 5             20/03/2022                     4
# ..              ...                    ...                   ...
# 152             160             09/06/2022                     2
# 153             161             06/06/2022                     1
# 154             145             04/06/2022                     4
# 155             154             08/06/2022                     2
# 156             160             09/06/2022                     2
#
#      Valor promedio de la compra  Categoría de productos comprados  Edad  \
# 0                          200.5                               1.0  32.0
# ...

# %% [markdown]
# # **Renombrar columnas de un Dataframe**

# %%
# Renombrar columnas
df.columns= ["id_cliente", "ultima_fecha_compra","frecuencia_compra","valor_promedio_compra","categoria_compra","edad", "pago_efectivo", "pago_credito", "pago_transferencia"]
df
# Out:
#      id_cliente ultima_fecha_compra  frecuencia_compra  valor_promedio_compra  \
# 0             1          15/03/2022                  5                  200.5
# 1             2          01/04/2022                  2                   80.0
# 2             3          10/12/2021                  3                  150.2
# 3             4          28/02/2022                  1                  300.0
# 4             5          20/03/2022                  4                   75.8
# ..          ...                 ...                ...                    ...
# 152         160          09/06/2022                  2                   50.0
# 153         161          06/06/2022                  1                  120.0
# 154         145          04/06/2022                  4                   75.2
# 155         154          08/06/2022                  2                   80.0
# 156         160          09/06/2022                  2                   50.0
#
# ...

# %% [markdown]
# # **Exportar archivo**

# %%
# Exportar archivo
df.to_csv("clientes_limpios.csv", index=False)
